# %% [markdown]
# More important in this pipeline is to integrate a possible back-up answer provided by the machine in the general model. The answers will be given as part of the E2E model initiated in the NIU, similar to secondary flow chit chats. Two important aspects impact the model:
#
# •	The type of the back-up answer (1.1 linked with task-oriented requests, 1.2 related to main NER 1.0 – another core input);
#
# •	Not to duplicate responses and have a common classifying rule for states with a consistent AVM for all types of reactions/actions of the bot.

# %%
# IN: initiations for back-up answer
# OUT: NOG complete solutions

# %%
# insert code to implement the following table and the additional requirements:
# 1.	If NOG is a solution, then NLG enhancements will be assessed in order to establish if the answer will be formal or informal, or an avatar change is necessary.
# 2.	At this stage, Dialogue and Discourse states will be treated the same (we are after the additional/confirmation questions possible phase).
# *the bot is multi-domain and the user is using core-NER for more domains

# %% [markdown]
# ![image.png](data:image/png;base64,...)
