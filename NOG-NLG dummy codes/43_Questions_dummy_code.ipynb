# %%
# IN: question initiations by states
# Bot actions - questions + initiations of other states

# %%
# add code for the implementation of the following table
# Attention not to duplicate Questions – Check AVM before answering

# %% [markdown]
# ![image.png](data:image/png;base64,...)
