# %%
# IN: initialization of change topic
# OUT: bot actions

# %%
# add code to implement the following table
# Attention not to duplicate – Check AVM before answering

# %% [markdown]
# ![image.png](data:image/png;base64,...)
