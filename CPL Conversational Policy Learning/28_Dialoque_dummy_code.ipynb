# %% [markdown]
# They are very similar with discourse policies, with 3 important differences:
#
# •	We will not ask for additional information or confirmations – the policies are straightforward.
#
# •	The bot will ask for detailed reviews, not for existing.
#
# •	This state has many interferences with user queries. User queries are defined as successive dialogues

# %%
# IN: CVM + Dialogue states
# OUT: dialoque policies that will be further assess in NOG layer

# %%
# insert code for:
# Applying policies depending on the evaluation of CVM and the type of the state;
# If more policies apply at the same time, the priority is: answer/review/confirmation/change topic/Disclaimer/ “l do not know” 
  # Check if the state is accurate. If not, reclassify the state 
  # Review 2 is for asking the future reviews

# %%
# adapt code for the following table implementation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
